# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline 
from matplotlib.pylab import rcParams 
rcParams['figure.figsize'] = 10, 6

# %%
dataset1 = pd.read_csv("FPCPITOTLZGUSA.csv")
dataset2 = pd.read_csv("T10YIEM (1).csv") 
dataset3 = pd.read_csv("US CPI.csv")
dataset1['DATE'] = pd.to_datetime(dataset1['DATE'], infer_datetime_format=True) 
dataset2['DATE'] = pd.to_datetime(dataset1['DATE'], infer_datetime_format=True) 
dataset3['DATE'] = pd.to_datetime(dataset1['DATE'], infer_datetime_format=True) 
indexedDataset1 = dataset1.set_index(['DATE']) 
indexedDataset2 = dataset2.set_index(['DATE']) 
indexedDataset3 = dataset3.set_index(['DATE'])

# %%
from datetime import datetime 
indexedDataset1.head(10) 
indexedDataset2.head(10)
indexedDataset3.head(10)

# %%
plt.xlabel("Date") 
plt.ylabel("Inflation Number") 
plt.plot(indexedDataset1)  
plt.plot(indexedDataset2) 
plt.plot(indexedDataset3)
